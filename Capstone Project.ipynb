# %%
import requests 
import pandas as pd
import numpy as np 
import random 


# !pip install geopy
from geopy.geocoders import Nominatim 

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 9.3 MB/s  eta 0:00:01
# Collecting branca
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=41637e8bd928dde7cf098fb47aea0ddbe05b0e0c6c2993914bb21b8d54c4a05e
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.5.0
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'XLJ4PTEAWOGAO0IPFBMQO25O4STOL1RKTPMPGS3L0F41EFFN'
CLIENT_SECRET = 'CZYMHQOB5LMLQHUMBO4EHDGUXOFQQ43GTREMKE4YMHTRZTL0' 
ACCESS_TOKEN = 'SNTLLAUC0UJX1DFQ0NJEBSFZOANNUBQMYBZ5IISL1ISM5L0L'
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: XLJ4PTEAWOGAO0IPFBMQO25O4STOL1RKTPMPGS3L0F41EFFN
# CLIENT_SECRET:CZYMHQOB5LMLQHUMBO4EHDGUXOFQQ43GTREMKE4YMHTRZTL0

# %%
address = 'New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7127281 -74.0060152

# %%
search_query = 'Restaurant'
radius = 500
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']


dataframe = json_normalize(venues)
dataframe.head()
# Out:
# Restaurant .... OK!
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                             name  \
# 0  45e5c256f964a52046431fe3  Mudville Restaurant & Tap House
# 1  4b4fdfc8f964a520801827e3     TJ Byrnes Bar and Restaurant
# 2  4bc238adf8219c744286b410         Amore's Pizza Restaurant
# 3  4c4890da1879c9b6cce6e143            New Shezan Restaurant
# 4  4b88199af964a520e6df31e3               Win Won Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14c941735', 'name': 'W...  v-1607891794    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1607891794    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1607891794    False
# 3  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...  v-1607891794    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1607891794    False
#
#   location.address         location.crossStreet  location.lat  location.lng  \
# 0  126 Chambers St  btwn W Broadway & Church St     40.715209    -74.008923
# 1     77 Fulton St                      Gold St     40.709233    -74.003747
# 2  147 Chambers St                Hudson Street     40.715860    -74.009888
# 3    183 Church St       btwn Duane & Reade St.     40.715789    -74.007227
# 4    10 Liberty Pl                  Maiden Lane     40.709193    -74.009344
#
#                              location.labeledLatLngs  ...  location.state  \
# 0  [{'label': 'entrance', 'lat': 40.715239, 'lng'...  ...              NY
# 1  [{'label': 'display', 'lat': 40.70923312629616...  ...              NY
# 2  [{'label': 'display', 'lat': 40.71585960614924...  ...              NY
# 3  [{'label': 'display', 'lat': 40.71578949233164...  ...              NY
# 4  [{'label': 'display', 'lat': 40.709193, 'lng':...  ...              NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [126 Chambers St (btwn W Broadway & Church St)...
# 1    United States  [77 Fulton St (Gold St), New York, NY 10038, U...
# 2    United States  [147 Chambers St (Hudson Street), New York, NY...
# 3    United States  [183 Church St (btwn Duane & Reade St.), New Y...
# 4    United States  [10 Liberty Pl (Maiden Lane), New York, NY 100...
#
#   delivery.id                                       delivery.url  \
# 0      299726  https://www.seamless.com/menu/mudville-restaur...
# 1       64746  https://www.seamless.com/menu/tj-byrnes-77-ful...
# 2     1431324  https://www.seamless.com/menu/cafe-amores-pizz...
# 3     1237998  https://www.seamless.com/menu/sheezan-restaura...
# 4         NaN                                                NaN
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0               seamless  https://fastly.4sqi.net/img/general/cap/
# 1               seamless  https://fastly.4sqi.net/img/general/cap/
# 2               seamless  https://fastly.4sqi.net/img/general/cap/
# 3               seamless  https://fastly.4sqi.net/img/general/cap/
# 4                    NaN                                       NaN
#
#   delivery.provider.icon.sizes               delivery.provider.icon.name  \
# 0                     [40, 50]  /delivery_provider_seamless_20180129.png
# 1                     [40, 50]  /delivery_provider_seamless_20180129.png
# 2                     [40, 50]  /delivery_provider_seamless_20180129.png
# 3                     [40, 50]  /delivery_provider_seamless_20180129.png
# 4                          NaN                                       NaN
#
#   venuePage.id
# 0     43156651
# 1    131643631
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 24 columns]

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]


dataframe_filtered
# Out:
#                                 name                 categories  \
# 0    Mudville Restaurant & Tap House                Wings Joint
# 1       TJ Byrnes Bar and Restaurant                 Restaurant
# 2           Amore's Pizza Restaurant                Pizza Place
# 3              New Shezan Restaurant  Middle Eastern Restaurant
# 4                 Win Won Restaurant         Chinese Restaurant
# 5           Restaurant Marc Forgione    New American Restaurant
# 6                Restaurant at Smyth        American Restaurant
# 7                Edward's Restaurant        American Restaurant
# 8          Kaede Japanese Restaurant        Japanese Restaurant
# 9             Restaurant New Orleans  Cajun / Creole Restaurant
# 10             Roy Rogers Restaurant                       Food
# 11              Chen Hall Restaurant                       Food
# 12          Taste Chinese Restaurant         Chinese Restaurant
# 13             IL Mattone Restaurant         Italian Restaurant
# 14        M C Choi French Restaurant                       Food
# 15  Lilly O'Brien's Bar & Restaurant                   Dive Bar
# 16       20/20 Latin Club Restaurant         Spanish Restaurant
# 17       Caruso's Italian Restaurant         Italian Restaurant
# 18            Chamberlain Restaurant                       Food
# 19               Chinared Restaurant         Chinese Restaurant
# 20   Conca Cucina Italian Restaurant                       Food
# 21  Bangladeshi Pakistani Restaurant          Indian Restaurant
# 22      She Ja Meh Korean Restaurant          Korean Restaurant
# 23               Gloria's Restaurant         Italian Restaurant
# 24           Aoi Japanese Restaurant        Japanese Restaurant
# 25        Nagoya Japanese Restaurant                       Food
# 26        Nagoya Japanese Restaurant        Japanese Restaurant
# 27               Gn Restaurant Group                       Food
# 28          Pancho Magico Restaurant                       Food
# 29       Downtown Chinese Restaurant                       Food
#
#             address                    crossStreet        lat        lng  \
# 0   126 Chambers St    btwn W Broadway & Church St  40.715209 -74.008923
# 1      77 Fulton St                        Gold St  40.709233 -74.003747
# 2   147 Chambers St                  Hudson Street  40.715860 -74.009888
# 3     183 Church St         btwn Duane & Reade St.  40.715789 -74.007227
# 4     10 Liberty Pl                    Maiden Lane  40.709193 -74.009344
# 5      134 Reade St   btwn Hudson and Greenwich St  40.716380 -74.009629
# 6     85 W Broadway                Chambers Street  40.715206 -74.009132
# 7    136 W Broadway            btwn Duane & Thomas  40.716876 -74.008173
# 8    90 Chambers St                            NaN  40.714623 -74.007270
# 9      47 Fulton St                            NaN  40.707784 -74.004296
# 10     250 Broadway                            NaN  40.712978 -74.007812
# 11     10 Murray St                            NaN  40.713341 -74.008095
# 12    178 Church St                            NaN  40.715690 -74.007605
# 13      61 Reade St    bet- broadway and church st  40.714730 -74.006716
# 14    200 Church St                            NaN  40.716171 -74.007172
# 15     18 Murray St  btwn Broadway & Greenwich St.  40.713552 -74.008556
# 16     20 Warren St                            NaN  40.714249 -74.007614
# 17      42 Broadway                            NaN  40.710509 -74.008276
# 18    141 Fulton St                            NaN  40.710346 -74.007990
# 19              NaN                            NaN  40.715219 -74.008647
# 20    63 W Broadway                            NaN  40.714484 -74.009806
# 21    183 Church St                       Duane ST  40.715693 -74.007052
# 22       26 John St                            NaN  40.709599 -74.008614
# 23   107 W Broadway                       Reade St  40.715794 -74.008789
# 24     325 Broadway                            NaN  40.716120 -74.005278
# 25     59 Nassau St                            NaN  40.709251 -74.008797
# 26     49 Fulton St                            NaN  40.708168 -74.003960
# 27  167 Chambers St                            NaN  40.716357 -74.010477
# 28     213 Pearl St                            NaN  40.707199 -74.006500
# 29      135 John St                            NaN  40.707134 -74.004944
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'entrance', 'lat': 40.715239, 'lng'...       369      10007
# 1   [{'label': 'display', 'lat': 40.70923312629616...       433      10038
# 2   [{'label': 'display', 'lat': 40.71585960614924...       477      10007
# 3   [{'label': 'display', 'lat': 40.71578949233164...       355      10007
# 4   [{'label': 'display', 'lat': 40.709193, 'lng':...       483      10038
# 5   [{'label': 'display', 'lat': 40.71637984317071...       508      10013
# 6   [{'label': 'display', 'lat': 40.71520614624023...       381      10007
# 7   [{'label': 'display', 'lat': 40.71687606616411...       496      10013
# 8   [{'label': 'display', 'lat': 40.71462286117167...       236      10007
# 9   [{'label': 'display', 'lat': 40.707784, 'lng':...       569      10038
# 10  [{'label': 'display', 'lat': 40.71297836303711...       154      10007
# 11  [{'label': 'display', 'lat': 40.71334075927734...       188      10007
# 12  [{'label': 'display', 'lat': 40.7156902, 'lng'...       355      10013
# 13  [{'label': 'display', 'lat': 40.71472999999999...       230      10007
# 14  [{'label': 'display', 'lat': 40.71617126464844...       395      10013
# 15  [{'label': 'display', 'lat': 40.71355194794925...       233      10007
# 16  [{'label': 'display', 'lat': 40.71424865722656...       216      10007
# 17  [{'label': 'display', 'lat': 40.71050909999999...       312      10004
# 18  [{'label': 'display', 'lat': 40.710346, 'lng':...       313      10038
# 19  [{'label': 'display', 'lat': 40.71521948601532...       355      10013
# 20  [{'label': 'display', 'lat': 40.71448400000000...       374      10007
# 21  [{'label': 'display', 'lat': 40.715693, 'lng':...       341      10007
# 22  [{'label': 'display', 'lat': 40.70959854125976...       411      10038
# 23  [{'label': 'display', 'lat': 40.71579360961914...       413      10013
# 24  [{'label': 'display', 'lat': 40.71612035753943...       382      10007
# 25  [{'label': 'display', 'lat': 40.70925140380859...       452      10038
# 26  [{'label': 'entrance', 'lat': 40.708304, 'lng'...       536      10038
# 27  [{'label': 'display', 'lat': 40.716357, 'lng':...       552      10007
# 28  [{'label': 'display', 'lat': 40.70719909667969...       616      10038
# 29  [{'label': 'entrance', 'lat': 40.707098, 'lng'...       629      10038
#
#     cc      city state        country  \
# 0   US  New York    NY  United States
# 1   US  New York    NY  United States
# 2   US  New York    NY  United States
# 3   US  New York    NY  United States
# 4   US  New York    NY  United States
# 5   US  New York    NY  United States
# 6   US  New York    NY  United States
# 7   US  New York    NY  United States
# 8   US  New York    NY  United States
# 9   US  New York    NY  United States
# 10  US  New York    NY  United States
# 11  US  New York    NY  United States
# 12  US  New York    NY  United States
# 13  US  New York    NY  United States
# 14  US  New York    NY  United States
# 15  US  New York    NY  United States
# 16  US  New York    NY  United States
# 17  US  New York    NY  United States
# 18  US  New York    NY  United States
# 19  US  New York    NY  United States
# 20  US  New York    NY  United States
# 21  US  New York    NY  United States
# 22  US  New York    NY  United States
# 23  US  New York    NY  United States
# 24  US  New York    NY  United States
# 25  US  New York    NY  United States
# 26  US  New York    NY  United States
# 27  US  New York    NY  United States
# 28  US  New York    NY  United States
# 29  US  New York    NY  United States
#
#                                      formattedAddress  \
# 0   [126 Chambers St (btwn W Broadway & Church St)...
# 1   [77 Fulton St (Gold St), New York, NY 10038, U...
# 2   [147 Chambers St (Hudson Street), New York, NY...
# 3   [183 Church St (btwn Duane & Reade St.), New Y...
# 4   [10 Liberty Pl (Maiden Lane), New York, NY 100...
# 5   [134 Reade St (btwn Hudson and Greenwich St), ...
# 6   [85 W Broadway (Chambers Street), New York, NY...
# 7   [136 W Broadway (btwn Duane & Thomas), New Yor...
# 8   [90 Chambers St, New York, NY 10007, United St...
# 9   [47 Fulton St, New York, NY 10038, United States]
# 10  [250 Broadway, New York, NY 10007, United States]
# 11  [10 Murray St, New York, NY 10007, United States]
# 12  [178 Church St, New York, NY 10013, United Sta...
# 13  [61 Reade St (bet- broadway and church st), Ne...
# 14  [200 Church St, New York, NY 10013, United Sta...
# 15  [18 Murray St (btwn Broadway & Greenwich St.),...
# 16  [20 Warren St, New York, NY 10007, United States]
# 17   [42 Broadway, New York, NY 10004, United States]
# 18  [141 Fulton St, New York, NY 10038, United Sta...
# 19                [New York, NY 10013, United States]
# 20  [63 W Broadway, New York, NY 10007, United Sta...
# 21  [183 Church St (Duane ST), New York, NY 10007,...
# 22    [26 John St, New York, NY 10038, United States]
# 23  [107 W Broadway (Reade St), New York, NY 10013...
# 24  [325 Broadway, New York, NY 10007, United States]
# 25  [59 Nassau St, New York, NY 10038, United States]
# 26  [49 Fulton St, New York, NY 10038, United States]
# 27  [167 Chambers St, New York, NY 10007, United S...
# 28  [213 Pearl St, New York, NY 10038, United States]
# 29   [135 John St, New York, NY 10038, United States]
#
#                           id
# 0   45e5c256f964a52046431fe3
# 1   4b4fdfc8f964a520801827e3
# 2   4bc238adf8219c744286b410
# 3   4c4890da1879c9b6cce6e143
# 4   4b88199af964a520e6df31e3
# 5   48510cf9f964a520a5501fe3
# 6   525ab25d11d236eef03b8496
# 7   3fd66200f964a52076e31ee3
# 8   5464f27c498e2e01c60151af
# 9   4e4e4cfdbd4101d0d7a72faf
# 10  4f325c4a19836c91c7d024d8
# 11  4f32676619836c91c7d474f2
# 12  581299bb38fa2e54303f6891
# 13  545ea828498ebf35eac73ee4
# 14  4f32b24519836c91c7f0c696
# 15  49e559cff964a520c7631fe3
# 16  4bf6dc1ab182c9b644a2745a
# 17  4e4c4d28bd413c4cc66857a5
# 18  4f3285f719836c91c7e0204d
# 19  50bd16ebe4b0e319556ce014
# 20  4f3232e219836c91c7bfde94
# 21  4bd71dca4e32d13adabbc380
# 22  4e4c4ee8bd413c4cc66863d4
# 23  4c5de89e6ebe2d7f7955d42e
# 24  4e4e4c34bd4101d0d7a71f7d
# 25  4f326c4819836c91c7d658ff
# 26  4e4c4fbdbd413c4cc66869c3
# 27  4f3215b919836c91c7b43f24
# 28  4f32544219836c91c7cd0334
# 29  4f320f6d19833175d60c8d97

# %% [markdown]
# ## Generating a Map

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius= 0.4,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'Tourist Site'
radius = 500
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']


dataframe = json_normalize(venues)
dataframe.head()
# Out:
# Tourist Site .... OK!
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                          name  \
# 0  5deb3e9ba5bc0c000b5e83ff                 Geeks On Site
# 1  5278fc2c498e8a53962a5c94  Poll Site: Southbridge Tower
# 2  57b9dda3498e876beb013404    9/11 Memorial Preview Site
# 3  4e258c621f6ee0c70a6048e8                          SITE
# 4  4ddd27fe22713339cd2601e9          3 World Trade Center
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '52f2ab2ebcbc57f1066b8b2f', 'name': 'O...  v-1607892288    False
# 1  [{'id': '4f2a210c4b9023bd5841ed28', 'name': 'H...  v-1607892288    False
# 2  [{'id': '4bf58dd8d48988d128951735', 'name': 'G...  v-1607892288    False
# 3  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1607892288    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1607892288    False
#
#    location.address  location.lat  location.lng  \
# 0    52 Chambers St     40.713371    -74.005539
# 1    88 Beekman St.     40.708913    -74.005349
# 2               NaN     40.711455    -74.009956
# 3      25 Maiden Ln     40.709284    -74.008848
# 4  175 Greenwich St     40.710829    -74.011194
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.71337127685547...                 82
# 1  [{'label': 'display', 'lat': 40.708913, 'lng':...                428
# 2  [{'label': 'display', 'lat': 40.711455, 'lng':...                361
# 3  [{'label': 'display', 'lat': 40.70928400000000...                451
# 4  [{'label': 'display', 'lat': 40.71082891009877...                485
#
#   location.postalCode location.cc location.city location.state  \
# 0               10007          US      New York             NY
# 1                 NaN          US      New York             NY
# 2               10007          US      New York             NY
# 3               10038          US      New York             NY
# 4               10007          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [52 Chambers St, New York, NY 10007, United St...
# 1    United States      [88 Beekman St., New York, NY, United States]
# 2    United States                [New York, NY 10007, United States]
# 3    United States  [25 Maiden Ln (Nassau Streey), New York, NY 10...
# 4    United States  [175 Greenwich St (at Vesey St), New York, NY ...
#
#   location.crossStreet venuePage.id
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3        Nassau Streey          NaN
# 4          at Vesey St          NaN

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]


dataframe_filtered
# Out:
#                            name           categories           address  \
# 0                 Geeks On Site    Other Repair Shop    52 Chambers St
# 1  Poll Site: Southbridge Tower  Housing Development    88 Beekman St.
# 2    9/11 Memorial Preview Site            Gift Shop               NaN
# 3                          SITE               Office      25 Maiden Ln
# 4          3 World Trade Center               Office  175 Greenwich St
# 5  FreshySites - Website Design                 None  66 West Broadway
#
#          lat        lng                                     labeledLatLngs  \
# 0  40.713371 -74.005539  [{'label': 'display', 'lat': 40.71337127685547...
# 1  40.708913 -74.005349  [{'label': 'display', 'lat': 40.708913, 'lng':...
# 2  40.711455 -74.009956  [{'label': 'display', 'lat': 40.711455, 'lng':...
# 3  40.709284 -74.008848  [{'label': 'display', 'lat': 40.70928400000000...
# 4  40.710829 -74.011194  [{'label': 'display', 'lat': 40.71082891009877...
# 5  40.714690 -74.010128  [{'label': 'display', 'lat': 40.71468968, 'lng...
#
#    distance postalCode  cc      city state        country  \
# 0        82      10007  US  New York    NY  United States
# 1       428        NaN  US  New York    NY  United States
# 2       361      10007  US  New York    NY  United States
# 3       451      10038  US  New York    NY  United States
# 4       485      10007  US  New York    NY  United States
# 5       410      10007  US  New York    NY  United States
#
#                                     formattedAddress    crossStreet  \
# 0  [52 Chambers St, New York, NY 10007, United St...            NaN
# 1      [88 Beekman St., New York, NY, United States]            NaN
# 2                [New York, NY 10007, United States]            NaN
# 3  [25 Maiden Ln (Nassau Streey), New York, NY 10...  Nassau Streey
# 4  [175 Greenwich St (at Vesey St), New York, NY ...    at Vesey St
# 5  [66 West Broadway, New York, NY 10007, United ...            NaN
#
#                          id
# 0  5deb3e9ba5bc0c000b5e83ff
# 1  5278fc2c498e8a53962a5c94
# 2  57b9dda3498e876beb013404
# 3  4e258c621f6ee0c70a6048e8
# 4  4ddd27fe22713339cd2601e9
# 5  5c7a26e366f3cd002c89b4e0

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius= 0.4,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %%
search_query = 'Restaurant'
radius = 500
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']


dataframe = json_normalize(venues)
dataframe.head()
# Out:
# Restaurant .... OK!
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                             name  \
# 0  4ad4c05ff964a52048f720e3  Hemispheres Restaurant & Bistro
# 1  4ae4b055f964a520229d21e3  Kyoto House Japanese Restaurant
# 2  5a7c3e079de23b294a2c4117            Restaurant | Adelaide
# 3  5a8b24b2018cbb6c4ca70dae       Hendricks Restaurant & Bar
# 4  4ad7929cf964a520500c21e3           The Senator Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1607892632    False
# 1  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1607892632    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1607892632    False
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1607892632    False
# 4  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...  v-1607892632    False
#
#           location.address  location.lat  location.lng  \
# 0      110 Chestnut Street     43.654884    -79.385931
# 1      143 Dundas St. West     43.655381    -79.385270
# 2  325 Bay St (31st floor)     43.649563    -79.380590
# 3          Yonge And Queen     43.653415    -79.379698
# 4      249 Victoria Street     43.655641    -79.379199
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                224
# 1  [{'label': 'display', 'lat': 43.65538110598594...                237
# 2  [{'label': 'display', 'lat': 43.649563, 'lng':...                512
# 3  [{'label': 'display', 'lat': 43.65341542752959...                341
# 4  [{'label': 'display', 'lat': 43.65564091455335...                450
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1                 NaN          CA       Toronto             ON
# 2                 M5H          CA       Toronto             ON
# 3             M5G 2H6          CA       Toronto             ON
# 4             M5B 1T8          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada          [143 Dundas St. West, Toronto ON, Canada]
# 2           Canada  [325 Bay St (31st floor), Toronto ON M5H, Canada]
# 3           Canada  [Yonge And Queen (Queen St), Toronto ON M5G 2H...
# 4           Canada  [249 Victoria Street (btwn Dundas St E and Shu...
#
#              location.crossStreet venuePage.id location.neighborhood
# 0                             NaN          NaN                   NaN
# 1                             NaN          NaN                   NaN
# 2                             NaN          NaN                   NaN
# 3                        Queen St          NaN                   NaN
# 4  btwn Dundas St E and Shuter St     55585058                   NaN

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]


dataframe_filtered
# Out:
#                                              name                  categories  \
# 0                 Hemispheres Restaurant & Bistro         American Restaurant
# 1                 Kyoto House Japanese Restaurant            Sushi Restaurant
# 2                           Restaurant | Adelaide                  Restaurant
# 3                      Hendricks Restaurant & Bar                  Restaurant
# 4                          The Senator Restaurant                       Diner
# 5             Richtree Natural Market Restaurants                  Restaurant
# 6                         New Treasure Restaurant          Dim Sum Restaurant
# 7                   Hong Shing Chinese Restaurant          Chinese Restaurant
# 8                         Osgoode Hall Restaurant     New American Restaurant
# 9                                T.&.C Restaurant            Asian Restaurant
# 10                   Yueh Tung Chinese Restaurant          Chinese Restaurant
# 11                                Cali Restaurant       Vietnamese Restaurant
# 12             Castries Bar & Five Way Restaurant        Caribbean Restaurant
# 13                               Maezo Restaurant           Indian Restaurant
# 14  Spring Rolls | Japanese Restaurant in Toronto            Theme Restaurant
# 15             Akashiro Japanese Restaurant & Bar            Sushi Restaurant
# 16                  Terrace Restaurant at Elmwood         American Restaurant
# 17                         Maezo Restaurant & Bar           Indian Restaurant
# 18                     Alio Restaurant & Wine Bar          Italian Restaurant
# 19                        Little India Restaurant           Indian Restaurant
# 20                  Yulla Asian Fusion Restaurant            Asian Restaurant
# 21                     Wah Too Seafood Restaurant          Chinese Restaurant
# 22                              Tundra Restaurant                  Restaurant
# 23                   Vineyard Jamaican Restaurant        Caribbean Restaurant
# 24                              Anoush Restaurant                  Restaurant
# 25                        The Elm Tree Restaurant  Modern European Restaurant
# 26                        Joe's Indian Restaurant           Indian Restaurant
# 27                   Mt. Fuji Japanese Restaurant         Japanese Restaurant
# 28                                 Cru Restaurant                  Restaurant
# 29                           Donatello Restaurant          Italian Restaurant
#
#                      address        lat        lng  \
# 0        110 Chestnut Street  43.654884 -79.385931
# 1        143 Dundas St. West  43.655381 -79.385270
# 2    325 Bay St (31st floor)  43.649563 -79.380590
# 3            Yonge And Queen  43.653415 -79.379698
# 4        249 Victoria Street  43.655641 -79.379199
# 5              14 Queen St W  43.652614 -79.380231
# 6            150 Dundas St W  43.655384 -79.385362
# 7            195 Dundas St W  43.654925 -79.387089
# 8             130 Queen St W  43.651979 -79.385049
# 9            124 Chestnut St  43.655165 -79.385847
# 10         126 Elizabeth St.  43.655281 -79.385337
# 11         179 Dundas St. W.  43.655068 -79.386375
# 12                       NaN  43.654728 -79.380928
# 13       67 Richmond St West  43.651395 -79.381888
# 14    40 Dundas St W Box 36,  43.656105 -79.383495
# 15             220 Yonge St.  43.655965 -79.380541
# 16                       NaN  43.656101 -79.381480
# 17   67 Richmond Street West  43.651091 -79.381843
# 18           108 Dundas St W  43.655655 -79.384124
# 19           255 Queen St. W  43.650319 -79.388998
# 20                       NaN  43.651587 -79.379232
# 21            56 Centre Ave.  43.654833 -79.387206
# 22  145 Richmond Street West  43.650069 -79.385409
# 23                       NaN  43.649550 -79.380780
# 24           250 Dundas St W  43.654588 -79.389692
# 25                 43 Elm St  43.657397 -79.383761
# 26                       NaN  43.658150 -79.381563
# 27                       NaN  43.658555 -79.384992
# 28              100 Yonge St  43.649820 -79.378350
# 29                37 Elm St.  43.657489 -79.383605
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.65488413420439...       224    M5G 1R3
# 1   [{'label': 'display', 'lat': 43.65538110598594...       237        NaN
# 2   [{'label': 'display', 'lat': 43.649563, 'lng':...       512        M5H
# 3   [{'label': 'display', 'lat': 43.65341542752959...       341    M5G 2H6
# 4   [{'label': 'display', 'lat': 43.65564091455335...       450    M5B 1T8
# 5   [{'label': 'display', 'lat': 43.65261436174172...       313    M5H 3X4
# 6   [{'label': 'display', 'lat': 43.65538444237565...       240        NaN
# 7   [{'label': 'display', 'lat': 43.65492521335936...       300    M5G 1C7
# 8   [{'label': 'display', 'lat': 43.65197895903515...       189    M5H 2N6
# 9   [{'label': 'display', 'lat': 43.655165, 'lng':...       242    M5G 1R3
# 10  [{'label': 'display', 'lat': 43.65528126342919...       229    M5G 1P5
# 11  [{'label': 'display', 'lat': 43.65506808, 'lng...       264        M5G
# 12  [{'label': 'display', 'lat': 43.65472793579101...       279        NaN
# 13  [{'label': 'display', 'lat': 43.6513954168839,...       284    M5H 1W2
# 14  [{'label': 'display', 'lat': 43.65610515821675...       294    M5G 2C2
# 15  [{'label': 'display', 'lat': 43.65596504293232...       388        NaN
# 16  [{'label': 'display', 'lat': 43.65610066909799...       352        NaN
# 17  [{'label': 'display', 'lat': 43.65109052088520...       315    M5H 1Z5
# 18  [{'label': 'display', 'lat': 43.65565507065502...       242    M5G 1C3
# 19  [{'label': 'display', 'lat': 43.65031880877208...       538    M5V 1Z4
# 20  [{'label': 'display', 'lat': 43.651587, 'lng':...       433        NaN
# 21  [{'label': 'display', 'lat': 43.65483285234745...       303    M5G 1R5
# 22  [{'label': 'display', 'lat': 43.65006885787859...       398    M5H 2L2
# 23  [{'label': 'display', 'lat': 43.64955, 'lng': ...       506        NaN
# 24  [{'label': 'display', 'lat': 43.654588, 'lng':...       479    M5T 2Z5
# 25  [{'label': 'display', 'lat': 43.65739749535259...       436    M5G 1H1
# 26  [{'label': 'display', 'lat': 43.65814977325445...       553        NaN
# 27  [{'label': 'display', 'lat': 43.658555, 'lng':...       571        NaN
# 28  [{'label': 'display', 'lat': 43.64982, 'lng': ...       607    M5C 2W1
# 29  [{'label': 'display', 'lat': 43.65748931028801...       446    M5G 1H1
#
#     cc     city state country  \
# 0   CA  Toronto    ON  Canada
# 1   CA  Toronto    ON  Canada
# 2   CA  Toronto    ON  Canada
# 3   CA  Toronto    ON  Canada
# 4   CA  Toronto    ON  Canada
# 5   CA  Toronto    ON  Canada
# 6   CA  Toronto    ON  Canada
# 7   CA  Toronto    ON  Canada
# 8   CA      NaN   NaN  Canada
# 9   CA  Toronto    ON  Canada
# 10  CA  Toronto    ON  Canada
# 11  CA  Toronto    ON  Canada
# 12  CA      NaN   NaN  Canada
# 13  CA  Toronto    ON  Canada
# 14  CA  Toronto    ON  Canada
# 15  CA  Toronto    ON  Canada
# 16  CA      NaN   NaN  Canada
# 17  CA  Toronto    ON  Canada
# 18  CA  Toronto    ON  Canada
# 19  CA  Toronto    ON  Canada
# 20  CA  Toronto    ON  Canada
# 21  CA  Toronto    ON  Canada
# 22  CA  Toronto    ON  Canada
# 23  CA   Bolton    ON  Canada
# 24  CA  Toronto    ON  Canada
# 25  CA  Toronto    ON  Canada
# 26  CA      NaN   NaN  Canada
# 27  CA  Toronto    ON  Canada
# 28  CA  Toronto    ON  Canada
# 29  CA  Toronto    ON  Canada
#
#                                      formattedAddress  \
# 0   [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           [143 Dundas St. West, Toronto ON, Canada]
# 2   [325 Bay St (31st floor), Toronto ON M5H, Canada]
# 3   [Yonge And Queen (Queen St), Toronto ON M5G 2H...
# 4   [249 Victoria Street (btwn Dundas St E and Shu...
# 5         [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 6   [150 Dundas St W (at Elizabeth), Toronto ON, C...
# 7   [195 Dundas St W (at University Ave), Toronto ...
# 8   [130 Queen St W (University Ave), M5H 2N6, Can...
# 9       [124 Chestnut St, Toronto ON M5G 1R3, Canada]
# 10  [126 Elizabeth St. (Dundas St.), Toronto ON M5...
# 11  [179 Dundas St. W. (at Chestnut), Toronto ON M...
# 12                                           [Canada]
# 13  [67 Richmond St West, Toronto ON M5H 1W2, Canada]
# 14  [40 Dundas St W Box 36,, Toronto ON M5G 2C2, C...
# 15  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 16                                           [Canada]
# 17  [67 Richmond Street West (Richmond and Bay Str...
# 18  [108 Dundas St W (at Bay St.), Toronto ON M5G ...
# 19  [255 Queen St. W (Queen and University), Toron...
# 20                               [Toronto ON, Canada]
# 21       [56 Centre Ave., Toronto ON M5G 1R5, Canada]
# 22  [145 Richmond Street West (Hilton Toronto), To...
# 23                                [Bolton ON, Canada]
# 24      [250 Dundas St W, Toronto ON M5T 2Z5, Canada]
# 25      [43 Elm St (Bay), Toronto ON M5G 1H1, Canada]
# 26                                           [Canada]
# 27                               [Toronto ON, Canada]
# 28  [100 Yonge St (Yonge and King), Toronto ON M5C...
# 29  [37 Elm St. (at Bay St.), Toronto ON M5G 1H1, ...
#
#                              crossStreet        neighborhood  \
# 0                                    NaN                 NaN
# 1                                    NaN                 NaN
# 2                                    NaN                 NaN
# 3                               Queen St                 NaN
# 4         btwn Dundas St E and Shuter St                 NaN
# 5                                    NaN                 NaN
# 6                           at Elizabeth                 NaN
# 7                      at University Ave                 NaN
# 8                         University Ave                 NaN
# 9                                    NaN                 NaN
# 10                            Dundas St.                 NaN
# 11                           at Chestnut                 NaN
# 12                                   NaN                 NaN
# 13                                   NaN                 NaN
# 14                                   NaN                 NaN
# 15  in Toronto Eaton Centre Urban Eatery                 NaN
# 16                                   NaN                 NaN
# 17               Richmond and Bay Street                 NaN
# 18                            at Bay St.                 NaN
# 19                  Queen and University                 NaN
# 20                                   NaN                 NaN
# 21                                   NaN                 NaN
# 22                        Hilton Toronto                 NaN
# 23                                   NaN                 NaN
# 24                                   NaN                 NaN
# 25                                   Bay                 NaN
# 26                                   NaN                 NaN
# 27                                   NaN                 NaN
# 28                        Yonge and King  Financial District
# 29                            at Bay St.                 NaN
#
#                           id
# 0   4ad4c05ff964a52048f720e3
# 1   4ae4b055f964a520229d21e3
# 2   5a7c3e079de23b294a2c4117
# 3   5a8b24b2018cbb6c4ca70dae
# 4   4ad7929cf964a520500c21e3
# 5   4b295e10f964a520ba9d24e3
# 6   4b2a674ef964a52074a824e3
# 7   4b2027b5f964a520f82d24e3
# 8   4cffc78a75d3236a3b10e7f7
# 9   5f5eb99e0aea4b2a861bd0fa
# 10  52a7ae41498eed3af4d0a3fa
# 11  4c476d6719fde21e32410876
# 12  53ae6660498e1ac3c1282743
# 13  5b7618541ffe97002c1a13ae
# 14  56dd9d68498eb4e5edcb30f9
# 15  4fbbb3ace4b01e39077b4d55
# 16  4edbccaaf9abeea3db5268df
# 17  5834c90e110d032f3217f899
# 18  4ae9ef82f964a520cbb721e3
# 19  4ad8a5a7f964a5203c1321e3
# 20  4de827e4d4c0faa56428a51a
# 21  4c69740b8d22c9284d42b745
# 22  50ca02c0245f2d4aa8c2b313
# 23  4ba2ab4af964a520650e38e3
# 24  4b82c671f964a52016e430e3
# 25  539c6f13498e06f4cc765165
# 26  5165c333e4b07a7ad88d8a69
# 27  4c12b8ba82a3c9b6083ffaf8
# 28  5c636fa1492814002c0cb117
# 29  4afcc52df964a520b82522e3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius= 0.4,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'Tourist Site'
radius = 500
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']


dataframe = json_normalize(venues)
dataframe.head()
# Out:
# Tourist Site .... OK!
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id  \
# 0  5b119a2251950e002c1b7c4b
# 1  51ddc79f8bbdaf8d81195619
# 2  4f954b46e4b01143d3694220
# 3  58ee17adcf44512b7dec5c64
#
#                                                 name  \
# 0         Japan National Tourist Organization - JNTO
# 1  Birkbeck Building National Historic Site of Ca...
# 2                                           Sitecore
# 3                         Siteimprove, Inc. - Canada
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4f4530164b9074f6e4fb00ff', 'name': 'T...  v-1607892751    False
# 1  [{'id': '4deefb944765f83613cdba6e', 'name': 'H...  v-1607892751    False
# 2                                                 []  v-1607892751    False
# 3  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1607892751    False
#
#            location.address  location.lat  location.lng  \
# 0       481 University Ave.     43.650894    -79.386563
# 1        8-10 Adelaide St E     43.650640    -79.377530
# 2  65 Queen St E, Suite 615     43.651798    -79.382497
# 3          110 Yonge Street     43.650158    -79.378590
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.650894, 'lng':...                357
# 1  [{'label': 'display', 'lat': 43.65064026980357...                605
# 2  [{'label': 'display', 'lat': 43.65179830298299...                220
# 3  [{'label': 'display', 'lat': 43.650158, 'lng':...                567
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 2E9          CA       Toronto             ON
# 1                 NaN          CA       Toronto             ON
# 2                 NaN          CA       Toronto             ON
# 3             M5C 1T4          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [481 University Ave., Toronto ON M5G 2E9, Canada]
# 1           Canada  [8-10 Adelaide St E (Yonge & Adelaide), Toront...
# 2           Canada  [65 Queen St E, Suite 615 (Bay), Toronto ON, C...
# 3           Canada  [110 Yonge Street (Adelaide), Toronto ON M5C 1...
#
#   location.crossStreet
# 0                  NaN
# 1     Yonge & Adelaide
# 2                  Bay
# 3             Adelaide

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]


dataframe_filtered
# Out:
#                                                 name  \
# 0         Japan National Tourist Organization - JNTO
# 1  Birkbeck Building National Historic Site of Ca...
# 2                                           Sitecore
# 3                         Siteimprove, Inc. - Canada
#
#                    categories                   address        lat        lng  \
# 0  Tourist Information Center       481 University Ave.  43.650894 -79.386563
# 1               Historic Site        8-10 Adelaide St E  43.650640 -79.377530
# 2                        None  65 Queen St E, Suite 615  43.651798 -79.382497
# 3                      Office          110 Yonge Street  43.650158 -79.378590
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.650894, 'lng':...       357    M5G 2E9  CA
# 1  [{'label': 'display', 'lat': 43.65064026980357...       605        NaN  CA
# 2  [{'label': 'display', 'lat': 43.65179830298299...       220        NaN  CA
# 3  [{'label': 'display', 'lat': 43.650158, 'lng':...       567    M5C 1T4  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [481 University Ave., Toronto ON M5G 2E9, Canada]
# 1  Toronto    ON  Canada  [8-10 Adelaide St E (Yonge & Adelaide), Toront...
# 2  Toronto    ON  Canada  [65 Queen St E, Suite 615 (Bay), Toronto ON, C...
# 3  Toronto    ON  Canada  [110 Yonge Street (Adelaide), Toronto ON M5C 1...
#
#         crossStreet                        id
# 0               NaN  5b119a2251950e002c1b7c4b
# 1  Yonge & Adelaide  51ddc79f8bbdaf8d81195619
# 2               Bay  4f954b46e4b01143d3694220
# 3          Adelaide  58ee17adcf44512b7dec5c64

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius= 0.4,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
